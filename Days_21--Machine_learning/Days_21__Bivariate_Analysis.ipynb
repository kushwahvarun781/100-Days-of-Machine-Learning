# %%
import pandas as pd
import seaborn as sns

# %%
titanic = pd.read_csv(r'C:\Users\ASUS\AppData\Local\Temp\1f5ce7bb-5f17-49c7-9c34-670ee478703d_archive (5).zip.03d\Titanic-Dataset.csv')
titanic.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
iris = pd.read_csv(r'C:\Users\ASUS\Downloads\iris.csv')
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
ai = pd.read_csv(r'C:\Users\ASUS\.jupyter\Machine_Learning_Campus_X\ai_student_impact.csv').sample(500)
ai
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 4865       104866       Business      Graduate             3.700
# 28187      128188       Business     Sophomore             3.687
# 43492      143493           Arts      Freshman             3.402
# 35991      135992        Medical        Junior             3.078
# 45213      145214       Business      Freshman             2.613
# ...           ...            ...           ...               ...
# 14288      114289           Arts        Senior             3.521
# 6650       106651           STEM      Freshman             3.429
# 42029      142030     Humanities     Sophomore             3.802
# 22084      122085           STEM        Senior             1.907
# 38090      138091       Business        Senior             3.058
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 4865                 1.73       Copywriting/Drafting                 Beginner
# ...

# %%
# bivariarte analysis
sns.scatterplot(data=ai,x='Weekly_GenAI_Hours',y='Skill_Retention_Score')
# Out:
# <Axes: xlabel='Weekly_GenAI_Hours', ylabel='Skill_Retention_Score'>

# %%
# multi variate analysis --> 3 variable
sns.scatterplot(data=ai,x='Weekly_GenAI_Hours',y='Skill_Retention_Score',hue='Prompt_Engineering_Skill')
# Out:
# <Axes: xlabel='Weekly_GenAI_Hours', ylabel='Skill_Retention_Score'>

# %%
# 4 variable
sns.scatterplot(data=ai,x='Weekly_GenAI_Hours',y='Skill_Retention_Score',hue='Prompt_Engineering_Skill',style='Paid_Subscription')
# Out:
# <Axes: xlabel='Weekly_GenAI_Hours', ylabel='Skill_Retention_Score'>

# %%
titanic.sample(3)
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 481          482         0       2        Frost, Mr. Anthony Wood "Archie"
# 204          205         1       3                Cohen, Mr. Gurshon "Gus"
# 558          559         1       1  Taussig, Mrs. Emil (Tillie Mandelbaum)
#
#         Sex   Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 481    male   NaN      0      0    239854   0.00   NaN        S
# 204    male  18.0      0      0  A/5 3540   8.05   NaN        S
# 558  female  39.0      1      1    110413  79.65   E67        S

# %%
###########  bar plot

sns.barplot(data = titanic ,x='Pclass',y='Age',hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
######## box plot

sns.boxplot(data=titanic,x='Sex',y='Age',hue='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
####### Dis plot 

sns.displot(data=titanic,x='Age',hue='Survived')

# %%
titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
#### Heat map

tit =  pd.crosstab(titanic['Pclass'],titanic['Survived'])
tit
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(tit)
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
titanic.groupby('Sex')['Survived'].mean()*100
# Out:
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %%
##### Cluster map

set = pd.crosstab(titanic['Parch'],titanic['Survived'])
set
# Out:
# Survived    0    1
# Parch
# 0         445  233
# 1          53   65
# 2          40   40
# 3           2    3
# 4           4    0
# 5           4    1
# 6           1    0

# %%
sns.clustermap(set)

# %%
####### Pair plot

iris.head(3)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %%
sns.pairplot(iris,hue='Species')

# %%
######### line plot

match = pd.read_csv(r'C:\Users\ASUS\Downloads\matches.csv')
match.head(3)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %%
runs = match.groupby('season')['win_by_runs'].sum().reset_index()
runs
# Out:
#    season  win_by_runs
# 0    2008          705
# 1    2009          764
# 2    2010          976
# 3    2011         1098
# 4    2012          960
# 5    2013         1241
# 6    2014          644
# 7    2015          850
# 8    2016          676
# 9    2017          788

# %%
sns.lineplot(data=runs,x='season',y='win_by_runs')
# Out:
# <Axes: xlabel='season', ylabel='win_by_runs'>
